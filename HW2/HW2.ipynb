# %%
# Sneha Dubey & Bastiaan Van Buiten
# Dr. Ghosh
# CSCI 183
# 12 February 2024
# Homework 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# import seaborn as sns

# %%
# housing.csv

# %%
#Q1:
df = pd.read_csv("housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
#Q2:
print(df.columns)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
#Q3:
df.head()
# Looking at the data, it appears that longitude, latitude, housing_median_range, total_bedrooms, population, households, median_income, and
# median_house_income are the numerical columns, with ocean_proximity being categorical (8 numerical, 1 categorical)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
#Q4:
df_num = df.drop(['ocean_proximity'], axis = 1)
df_num.corr()
# The only moderatly correlated features to median_house_value (the target) seem is median_income.
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# ...

# %%
# kc_house_data.csv

# %%
#Q1:
kc_df = pd.read_csv("kc_house_data.csv")
kc_df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#Q2:
print(kc_df.columns)
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#Q3:
kc_df.head()
# Looking at the data, it appears that bedrooms, bathrooms, sqft_living, sqft_loft, floors, sqft_above, sqft_basement,
# lat, long, sqft_living15, sqft_lot15 are the numerical features, with the rest being ordinal/categorical
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#Q4:
kc_df_num = kc_df.drop(['id', 'date', 'waterfront', 'view', 'condition', 'grade', 'yr_built', 'yr_renovated', 'zipcode'], axis = 1)
kc_df_num.corr()
# The high correlated feature to price (the target) is sqft_living. Additionally, bathrooms, sqft_above, and sqft_living15 are all 
# moderately corellated with price.
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308350   0.525138     0.702035  0.089661  0.256794
# bedrooms       0.308350  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.525138  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living    0.702035  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.256794  0.175429   0.500653     0.353949 -0.005201  1.000000
# sqft_above     0.605567  0.477600   0.685342     0.876597  0.183512  0.523885
# sqft_basement  0.323816  0.303093   0.283770     0.435043  0.015286 -0.245705
# lat            0.307003 -0.008931   0.024573     0.052529 -0.085683  0.049614
# long           0.021626  0.129473   0.223042     0.240223  0.229521  0.125419
# sqft_living15  0.585379  0.391638   0.568634     0.756420  0.144608  0.279885
# ...

# %%
#Q5 Graphs

# %%
plt.figure(figsize=(12, 6))
plt.plot(kc_df['price'], kc_df['bedrooms'], 'o')           # scatter plot showing actual data
plt.xlabel('price')
plt.ylabel('bedrooms')
plt.title('price vs bedrooms')

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(kc_df['price'], kc_df['bathrooms'], 'o')           # scatter plot showing actual data
plt.xlabel('price')
plt.ylabel('bathrooms')
plt.title('price vs bathrooms')

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(kc_df['price'], kc_df['sqft_living'], 'o')           # scatter plot showing actual data
plt.xlabel('price')
plt.ylabel('sqft_living')
plt.title('price vs sqft_living')

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(kc_df['price'], kc_df['sqft_lot'], 'o')           # scatter plot showing actual data
plt.xlabel('price')
plt.ylabel('sqft_lot')
plt.title('price vs sqft_lot')

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(kc_df['price'], kc_df['floors'], 'o')           # scatter plot showing actual data
plt.xlabel('price')
plt.ylabel('floors')
plt.title('price vs floors')

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(kc_df['price'], kc_df['sqft_above'], 'o')           # scatter plot showing actual data
plt.xlabel('price')
plt.ylabel('sqft_above')
plt.title('price vs sqft_above')

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(kc_df['price'], kc_df['sqft_basement'], 'o')           # scatter plot showing actual data
plt.xlabel('price')
plt.ylabel('sqft_basement')
plt.title('price vs sqft_basement')

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(kc_df['price'], kc_df['lat'], 'o')           # scatter plot showing actual data
plt.xlabel('price')
plt.ylabel('lat')
plt.title('price vs lat')

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(kc_df['price'], kc_df['long'], 'o')           # scatter plot showing actual data
plt.xlabel('price')
plt.ylabel('long')
plt.title('price vs long')

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(kc_df['price'], kc_df['sqft_living15'], 'o')           # scatter plot showing actual data
plt.xlabel('price')
plt.ylabel('sqft_living15')
plt.title('price vs sqft_living15')

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(kc_df['price'], kc_df['sqft_lot15'], 'o')           # scatter plot showing actual data
plt.xlabel('price')
plt.ylabel('sqft_lot15')
plt.title('price vs sqft_lot15')

plt.show()
